# %%
board={
    "p1":" ","p2":" ","p3":" ",
    "p4":" ","p5":" ","p6":" ",
    "p7":" ","p8":" ","p9":" "
}

player=1
count_moves=0
win=False

def check_win():
    global win
    
    #Horozontal
    if (all(borad[k]=="x" for k in ["p1","p2","p3"])) or (all(borad[k]=="x" for k in ["p4","p5","p6"])) or (all(borad[k]=="x" for k in ["p7","p8","p9"])):     
    print("player 01 won the game(-)")
    win=True
    
        if (all(borad[k]=="o" for k in ["p1","p2","p3"])) or (all(borad[k]=="o" for k in ["p4","p5","p6"])) or (all(borad[k]=="o" for k in ["p7","p8","p9"])):
    print("player 02 won the game(-)")
    win=True
    
    #vertical
      if (all(borad[k]=="x" for k in ["p1","p2","p3"])) or (all(borad[k]=="x" for k in ["p4","p5","p6"])) or (all(borad[k]=="x" for k in ["p7","p8","p9"])):
    print("player 01 won the game(|)")
    win=True
    
        if (all(borad[k]=="o" for k in ["p1","p2","p3"])) or (all(borad[k]=="o" for k in ["p4","p5","p6"])) or (all(borad[k]=="o" for k in ["p7","p8","p9"])):
    print("player 02 won the game(|)")
    win=True
    
    #Diagonal
       if (all(borad[k]=="x" for k in ["p1","p2","p3"])) or (all(borad[k]=="x" for k in ["p4","p5","p6"])) or (all(borad[k]=="x" for k in ["p7","p8","p9"])):
    print("player 01 won the game(/ or\)")
    win=True
    
        if (all(borad[k]=="o" for k in ["p1","p2","p3"])) or (all(borad[k]=="o" for k in ["p4","p5","p6"])) or (all(borad[k]=="o" for k in ["p7","p8","p9"])):
    print("player 02 won the game(/ or\)")
    win=True
    
print("Let's start the game")

while True:
    print(borad["p1"]+"|"+borad["p2"]+"|"+borad["p3"])
    print("-|-|")
    print(borad["p4"]+"|"+borad["p5"]+"|"+borad["p6"])
    print("-|-|")
    print(borad["p7"]+"|"+borad["p8"]+"|"+borad["p9"])
    
    check_win()
    
    if count_moves==9 or win:
        break
    while True:
        if player==1:
            p1=input("player 01, Select the position: ")
            
            if(p1.upper()in borad) and (board[p1.upper()]==" "):
                borad[p1.upper()]="x"
                player=2
                break
            else:
                print("position is not available")
                continue
                
        else:
            p2=input("player 02, Select the position: ")
            
            if (p2.upper() in borad) and (borad[p2.upper()]==" "):
                borad[p2.upper()]="0"
                player=1
                break
                
            else:
                print("Position is not available")
                continue
                
    count_moves+=1
    print()
    print()
print("Game end...")
